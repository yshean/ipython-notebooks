# %% [markdown]
# # Filter Visualization
#
# Here we visualize filters and outputs using the autoencoder network architecture implemented in Caffe.
#
# (This page follows DeCAF visualizations originally by Yangqing Jia.)
#
# First, import required modules, set plotting parameters, and make sure you have the pretrained autoencoder model. In this example we test on UCSD anomaly detection dataset.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Make sure that caffe is on the python path:
caffe_root = '/opt/caffe/'
import sys
sys.path.insert(0, caffe_root + 'python')

import caffe

plt.rcParams['figure.figsize'] = (10, 10)
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

MODEL_FILE = '/home/ucsd_autoencoder_deploy.prototxt'
PRETRAINED = '/home/ucsd_autoencoder_nesterov_full_image_weight_decay_00005_iter_80000.caffemodel'
IMAGE_FILE = '/home/Test_Full/Test001_001.jpg'

# %% [markdown]
# Set Caffe to GPU mode, load the net in the test phase for inference, and configure input preprocessing.

# %%
caffe.set_mode_gpu()
# caffe.TEST means that we load the net in the test phase
# To load the net in the train phase simply change it to caffe.TRAIN
net = caffe.Net(MODEL_FILE, PRETRAINED, caffe.TEST)

# input preprocessing: 'data' is the name of the input blob == net.inputs[0]
transformer = caffe.io.Transformer({'data': net.blobs['data'].data.shape})
# transformer.set_transpose('data', (2,0,1))
# Uncomment below when the mean image is available in .npy format
# transformer.set_mean('data', np.load(caffe_root + 'python/caffe/imagenet/ilsvrc_2012_mean.npy').mean(1).mean(1)) # mean pixel
transformer.set_raw_scale('data', 255)  # the reference model operates on images in [0,255] range instead of [0,1]
# transformer.set_channel_swap('data', (2,1,0))  # the reference model has channels in BGR order instead of RGB

# %% [markdown]
# Calculate the reconstruction error of the image by reshaping the net for the single input then doing the forward pass.

# %%
# net.blobs['data'].reshape(1,80,80)
input_image = caffe.io.load_image(IMAGE_FILE)
input_image = caffe.io.resize_image(input_image, (80,80))
input_image = np.dot(input_image[:,:,:3], [.299, .587, .114] )
input_image1 = np.copy(input_image)

# net.blobs['data'].data[...] = transformer.preprocess('data', input_image)
caffe_input = np.zeros((1,80,80))
# Swap axes from (80,80,1) to (1,80,80)
# Now is (80,80,1), swap to (1,80,80)
# input_image = np.swapaxes(input_image1,0,2)
# Now is (1,80,80), we want (1,80,80)
input_image = np.swapaxes(input_image,0,1)
caffe_input[0,:,:] = input_image[:,:]

net.blobs['data'].data[...] = caffe_input
out = net.forward()
print("The cross entropy loss is {}.".format(out['cross_entropy_loss']))
print("The L2 error is {}.".format(out['l2_error']))
# Out:
# The cross entropy loss is [[[[ 4419.06982422]]]].
# The L2 error is [[[[ 154.90724182]]]].

# %% [markdown]
# The layer features and their shapes (1 is the batch size, corresponding to the single input image in this example).

# %%
[(k, v.data.shape) for k, v in net.blobs.items()]
# Out:
# [('data', (1, 1, 80, 80)),
#  ('data_input_0_split_0', (1, 1, 80, 80)),
#  ('data_input_0_split_1', (1, 1, 80, 80)),
#  ('flatdata', (1, 6400, 1, 1)),
#  ('flatdata_flatdata_0_split_0', (1, 6400, 1, 1)),
#  ('flatdata_flatdata_0_split_1', (1, 6400, 1, 1)),
#  ('encode1', (1, 3000, 1, 1)),
#  ('encode1neuron', (1, 3000, 1, 1)),
#  ('encode2', (1, 1500, 1, 1)),
#  ('encode2neuron', (1, 1500, 1, 1)),
#  ('encode3', (1, 750, 1, 1)),
#  ('encode3neuron', (1, 750, 1, 1)),
#  ('encode4', (1, 90, 1, 1)),
#  ('decode4', (1, 750, 1, 1)),
#  ('decode4neuron', (1, 750, 1, 1)),
#  ('decode3', (1, 1500, 1, 1)),
#  ('decode3neuron', (1, 1500, 1, 1)),
#  ('decode2', (1, 3000, 1, 1)),
#  ('decode2neuron', (1, 3000, 1, 1)),
#  ('decode1', (1, 6400, 1, 1)),
#  ('decode1_decode1_0_split_0', (1, 6400, 1, 1)),
#  ('decode1_decode1_0_split_1', (1, 6400, 1, 1)),
#  ('cross_entropy_loss', (1, 1, 1, 1)),
#  ('decode1neuron', (1, 6400, 1, 1)),
#  ('l2_error', (1, 1, 1, 1))]

# %% [markdown]
# The parameters and their shapes. The parameters are `net.params['name'][0]` while biases are `net.params['name'][1]`.

# %%
[(k, v[0].data.shape) for k, v in net.params.items()]
# Out:
# [('encode1', (1, 1, 3000, 6400)),
#  ('encode2', (1, 1, 1500, 3000)),
#  ('encode3', (1, 1, 750, 1500)),
#  ('encode4', (1, 1, 90, 750)),
#  ('decode4', (1, 1, 750, 90)),
#  ('decode3', (1, 1, 1500, 750)),
#  ('decode2', (1, 1, 3000, 1500)),
#  ('decode1', (1, 1, 6400, 3000))]

# %% [markdown]
# ### Helper functions for visualization

# %%
# take an array of shape (n, height, width) or (n, height, width, channels)
# and visualize each (height, width) thing in a grid of size approx. sqrt(n) by sqrt(n)
def vis_square(data, padsize=1, padval=0):
    data -= data.min()
    data /= data.max()
    
    # force the number of filters to be square
    n = int(np.ceil(np.sqrt(data.shape[0])))
    padding = ((0, n ** 2 - data.shape[0]), (0, padsize), (0, padsize)) + ((0, 0),) * (data.ndim - 3)
    data = np.pad(data, padding, mode='constant', constant_values=(padval, padval))
    
    # tile the filters into an image
    data = data.reshape((n, n) + data.shape[1:]).transpose((0, 2, 1, 3) + tuple(range(4, data.ndim + 1)))
    data = data.reshape((n * data.shape[1], n * data.shape[3]) + data.shape[4:])
    
    plt.imshow(data)

# %% [markdown]
# The input image

# %%
# plt.imshow(transformer.deprocess('data', net.blobs['data'].data[0]))
# Or run the original image
plt.imshow(input_image1)

# %% [markdown]
# #### The first layer filters, `encode1`
#
# There are 3000 filters, each of which has dimension 3000x6400x1. We show only the first 48 filters, with each channel shown separately, so that each filter is a row.

# %%
# the parameters are a list of [weights, biases]
filters = net.params['encode1'][0].data
vis_square(filters[:48].reshape(1**2, 3000, 6400))

# %% [markdown]
# The first layer output, `encode1` (rectified responses of the filters above, first 36 of 2400 channels only)

# %%
feat = net.blobs['encode1'].data[0,:36]
vis_square(feat, padval=1)

# %% [markdown]
# #### The second layer filters, `encode2`
#
# There are 1500 filters, each of which has dimension 1500x3000x1. We show only the first 48 filters, with each channel shown separately, so that each filter is a row.

# %%
filters = net.params['encode2'][0].data
vis_square(filters[:48].reshape(1**2, 1500, 3000))

# %% [markdown]
# The second layer output, `encode2` (rectified, only the first 36 of 1500 channels)

# %%
feat = net.blobs['encode2'].data[0,:36]
vis_square(feat, padval=1)

# %% [markdown]
# #### The third layer output, `encode3` (rectified, all 750 channels)

# %%
feat = net.blobs['encode3'].data[0]
vis_square(feat, padval=0.5)

# %% [markdown]
# #### The fourth layer output, `encode4` (rectified, all 90 channels)

# %%
feat = net.blobs['encode4'].data[0]
vis_square(feat, padval=0.5)

# %% [markdown]
# #### The fifth layer output, `decode4` (rectified, all 750 channels)

# %%
feat = net.blobs['decode4'].data[0]
vis_square(feat, padval=0.5)

# %% [markdown]
# The fifth layer after applying sigmoid function, `decode4neuron`

# %%
feat = net.blobs['decode4neuron'].data[0]
vis_square(feat, padval=1)

# %% [markdown]
# #### The last (eighth) layer output, `decode1` (rectified)
#
# We show the output values and the histogram of the positive values.

# %%
feat = net.blobs['decode1'].data[0]
plt.subplot(2, 1, 1)
plt.plot(feat.flat)
plt.subplot(2, 1, 2)
_ = plt.hist(feat.flat[feat.flat > 0], bins=100)

# %% [markdown]
# #### The final cross entropy loss output, `cross_entropy_loss`

# %%
net.blobs['cross_entropy_loss'].data[0]
# Out:
# array([[[ 4419.06982422]]], dtype=float32)

# %% [markdown]
# #### The final L2 error output, `l2_error`

# %%
net.blobs['l2_error'].data[0]
# Out:
# array([[[ 154.90724182]]], dtype=float32)
